# %%
#qr code: Meet Captain W. Whitman @ 328 Mickle Street

# %%
S=[]

S.append("dummyline 0")
S.append("O Captain! My Captain! our fearful trip is done;")
S.append("The ship has weather'd every rack, the prize we sought is won;")
S.append("The port is near, the bells I hear, the people all exulting,")
S.append("While follow eyes the steady keel, the vessel grim and daring:")
S.append("But O heart! heart! heart!")
S.append("O the bleeding drops of red,")
S.append("Where on the deck my Captain lies,")
S.append("Fallen cold and dead.")
S.append("O Captain! My Captain! rise up and hear the bells;")
S.append("Rise up—for you the flag is flung—for you the bugle trills;")
S.append("For you bouquets and ribbon'd wreaths—for you the shores a-crowding;")
S.append("For you they call, the swaying mass, their eager faces turning;")
S.append("Here captain! dear father!")
S.append("This arm beneath your head;")
S.append("It is some dream that on the deck,")
S.append("You've fallen cold and dead.")
S.append("My Captain does not answer, his lips are pale and still;")
S.append("My father does not feel my arm, he has no pulse nor will;")
S.append("The ship is anchor'd safe and sound, its voyage closed and done;")
S.append("From fearful trip, the victor ship, comes in with object won;")
S.append("Exult, O shores, and ring, O bells!")
S.append("But I, with mournful tread,")
S.append("Walk the deck my captain lies,")
S.append("Fallen cold and dead.")

# %%
#15.00 1.41 6.01 13.21 6.03 9.07 10.02 8.15 23.05 2.52 3.02 11.56
#7.29 23.22 2.16 14.14 6.06 21.13 5.03 2.13 11.09 15.15 11.57 20.59
#17.36 2.58 19.01 16.01 1.01 18.24 3.14 24.19 20.39 6.23 5.24 2.52
#8.04 21.26 4.60 13.17 16.24 1.18 4.35 12.18 11.62 19.44 9.23

# %%
LINES=[15,1,6,13,6,9,10,8,23,2,3,11,7,23,2,14,6,21,5,2,11,15,11,20,17,2,19,16,1,18,3,24,20,6,5,2,8,21,4,13,16,1,4,12,11,19,9]
COLUMN=[0,41,1,21,3,7,2,15,5,52,2,56,29,22,16,14,7,13,3,13,9,15,57,59,36,58,1,1,1,24,14,19,39,23,24,52,4,26,60,17,24,18,35,18,62,44,23]

print(len(LINES))
print(len(COLUMN))

plain=""
c=0
for l in LINES:
  plain+=S[l][COLUMN[c]]
  c+=1
print (plain)
# Out:
# 47
# 47
# Is this the little woman who made the great war

# %%
#solution: Is this the little woman who made the great war
# Harriet Beecher Stowe

#solution challenge: HARRIET
