# %%
# message on fridge:                       dlsjvtl Av PumvythApvu ZljBypAF DpAopu Aol ZuvD

# decrypted(caesar) note:                  WELCOME TO INFORMATION SECURITY WITHIN THE SNOW

#decrypted pw                             welcome To InformaTion SecUriTY WiThin The SnoW
#Cryptool with upper and lower case:      Welcome to Information Security within the Snow


# ./snow  -C -p "Welcome to Information Security within the Snow" ./snow.txt
