# %%
# text ligt op zn zijkant (zwart is wit, wit is zwart)
# test: SOLVE FOR By FOUR TURNING GRILLE    RKER TPDO OTYG OPOH
# gebruik deze site: https://merricx.github.io/enigmator/cipher/grille.html  om de grille te klikken :-)

#oplossing KRYPTO THE POOR DOG
