# %%
# vermoeden 1) is dat dezelfde primes zijn gebruikt op N! N@ N3 te genereren
# dat zou betekeken dat gcd(N1,N2) of gcd(N2,N3) of gcd (N1,N3)  een priem moet opleveren:

# sage code

# %%
#vermoeden 2) lage e factor bestaat een aanval voor
#https://sage.hs-mittweida.de/home/pub/20/

# %%
na=009623511e6769644d693e89f692ffc2558eef121d42ca98699781e139e29c2e1aa58d8883bbdba41165fdeb85a9a5648fc29a65d59e9401694dd11ae205f0ce3b
nb=00ad4bc0f980f4523f490fc40c12efcecc1e8af67890b6562449876e8e091e861cda699e5a8eb309b0a9d6b293100c1229fbd18a5951f33b6fbab1fd8d90f7c829
nc=00b7223364d88353ec02b0850e8a01d2ba9ca2663c32c15df7b596406c6fc1c171ac965a554b8b338f4bb046c543937b4b19c699864f1d0dd4be0177eccce0bb57


ca=34d2fc2fa4785e1cdb1c09c9a5db98317d702aaedd2759d96e8938f740bf982e2a42b904e54dce016575142f1b0ed112cc214fa8378b0d5eebc036dc7df3eeea
cb=3ddd68eeff8be9fee7d667c3c0ef21ec0d56cefab0fa10199c933cffbf0924d486296c604a447f48b9f30905ee49dd7ceef8fc689a1c4c263c1b3a9505091b00
cc=956f7cbf2c9da7563365827aba8c66dc83c9fb77cf7ed0ca225e7d155d2f573d6bd18e1c18044cb14c59b52d3d1f6c38d8941a1d58942ed7f13a52caccc48154

e=3

# %%
#SAGE:

#ta = ca * (nb * nc) * inverse_mod(nb*nc, na)
#tb = cb * (na * nc) * inverse_mod(na*nc, nb)
#tc = cc * (na * nb) * inverse_mod(na*nb, nc)

#c = (ta + tb + tc) % (na*nb*nc)

#m = (c^(1/3))
#Solution 13989788739742427272277193015453900250111512583793201009668234415576204048672760581156999690701624926694924550547324254392117134178836228545125433044513

# %%
#reverse the solution from sage to text
import base64

inst=13989788739742427272277193015453900250111512583793201009668234415576204048672760581156999690701624926694924550547324254392117134178836228545125433044513
hexstring=str(hex(inst)[2:])
print (hexstring)
#hexstring to b64
i=0
b64string=""
while i < len(hexstring) -1:
  #print (hexstring[i:i+2])
  #print (chr(int(hexstring[i:i+2],16)))
  b64string+=(chr(int(hexstring[i:i+2],16)))
  i=i+2
print (b64string)
# Out:
# 4461732066756572206d6f7267656e206665737467656c65677465204d656574696e67206d75737320756e626564696e677420737461747466696e64656e21
# Das fuer morgen festgelegte Meeting muss unbedingt stattfinden!
