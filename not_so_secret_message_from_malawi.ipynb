# %%
#n=
#ct=
# e=17
#As a check, n mod 12347 is 7803 and ct mod 12347 is 1937

# %%
# use fermat factor algorithm to factor N
# sage code:

#def fermatfactor(N):
#       if N <= 0: return [N]
#       if is_even(N): return [2,N/2]
#       a = ceil(sqrt(N))
#       while not is_square(a^2-N):
#         a = a + 1
#       b = sqrt(a^2-N)
#       return [a - b,a + b]

# solution P and q:
#
#[17777324810733646969488445787976391269105128850805128551409042425916175469168770593916088768472336728042727873643069063316671869732507795155086000807594027, 
# 17777324810733646969488445787976391269105128850805128551409042425916175469483806303918279424710789334026260880628723893508382860291986009694703181381742497]

# compute d:
# phi = (p-1)*(q-1)
# d = inverse_mod(e,phi)

# d=

# %%
n=17

d=

import rsa

m=rsa.core.decrypt_int(ct, d, n)
print (str(bin(m)))
# Out:
# ...

# %%
#last 20 bytes: 01001101 01110101 01101100 01101001 01100010 01110111 01100001 01101110 01101010 01101001 00101110 01000111 01101111 01101111 01100100 01101101 01100001 01101001 01111010 01100101 01100011 01110010 01101111 01110000 00101110
#last 20 bytes:                         

# Mulibwanji.Goodmaizecrop.
