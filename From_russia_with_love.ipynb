# %%
CIPHER="CMGGJ  DBJP  WPQRWI  RWQR  OWQRMIKWI  VMP  IDSCR  BMIZ  WDIAMSC  ZT  GJWQWI  APWTW  HDSC  KDSC  ZT  QDGUWQRWP  CDWP  DI  HJQFMT  ZT  RPWAAWI  DI  GDWOW  KWDIW  QMPMC"

ALPHABET= "ABCDEFGHIJKLMNOPQRSTUVWXYZ "
#KEY=     "MUSKWABCDEFGHIJLNOPQRTVXYZ " #X E L Y
#auto     "muskwaocdxfghijyepqrtbvlnz"
KEY=      "MOSKWABCDEFGHIJLNPQRTUVXYZ "
plain= ""
for c in CIPHER:
  plain+=ALPHABET[KEY.index(c)]


print (plain)
print (CIPHER)
# Out:
# HALLO  IGOR  ERSTEN  TEST  BESTANDEN  WAR  NICHT  GANZ  EINFACH  ZU  LOESEN  FREUE  MICH  DICH  ZU  SILVESTER  HIER  IN  MOSKAU  ZU  TREFFEN  IN  LIEBE  DEINE  SARAH
# CMGGJ  DBJP  WPQRWI  RWQR  OWQRMIKWI  VMP  IDSCR  BMIZ  WDIAMSC  ZT  GJWQWI  APWTW  HDSC  KDSC  ZT  QDGUWQRWP  CDWP  DI  HJQFMT  ZT  RPWAAWI  DI  GDWOW  KWDIW  QMPMC
